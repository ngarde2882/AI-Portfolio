# %%
import random
import numpy as np
import pulp

def generate(k, n):
    P = np.random.randint(-100, 100, size=(k, n-k))
    I = np.eye(k)
    G = np.hstack((I, P))
    Psi = np.random.choice([-1,1], size=n-k) # m dependant for m in M: Psi_=Psi[:m]
    Y = list(range(n))
    a = Y.pop(random.randrange(len(Y)))
    b = Y.pop(random.randrange(len(Y)))
    X = np.array([]) # X starts empty and gets filled to the initial m-1=1 at the first iteration of LPsolver and increases every pass
    return G, P, Psi, a, b, X, Y

# %%
DEBUG = 0
def solve(n, k):
    M=list(range(n-k+1))[2:]
    print(f'solving n,k = {n,k}')
    print(f'over m = {M}')
    attempts = 0
    bounded = 0
    while True:
        if attempts%5000==0: print(f'{attempts} attempts reached\n{bounded} bounded solutions found')
        G, P, Psi, a, b, X, Y = generate(k, n)
        attempts += 1
        results = np.array([])
        for m in M:
            t = Y.pop(random.randrange(len(Y)))
            X = np.append(X, t)
            X = sorted(X)
            r = LPsolver(n, k, G, Psi[:m], a, b, X, Y)
            if r==-1:break
            bounded += 1
            results = np.append(results, r)
        if r==-1: continue
        print('G:\n',G)
        print('Ψ',Psi)
        print('a,b',a,b)
        print('X',X)
        print('Y',Y)
        return P, results
    print(f'{bounded} bounded soulutions in {attempts} attempts')
    return -1
def LPsolver(n, k, G, Psi, a, b, X, Y):
    # Define the LP maximization problem
    prob = pulp.LpProblem("Maximize", pulp.LpMaximize)

    # Create decision variables: u_i (assume non-negative; adjust bounds if necessary)
    U = [pulp.LpVariable(f"u_{i}", lowBound=0) for i in range(k)]
    # tau = [a] + X + [b] + Y
    # Objective function: maximize sum_i s0 * g[i] * u_i
    prob += pulp.lpSum(Psi[0] * G[i,a] * U[i] for i in range(k)), "Objective"
    for idx,j in enumerate(X):
        j = int(j)
        prob += pulp.lpSum((Psi[idx+1] * G[i,j] - Psi[0] * G[i,a]) * U[i] for i in range(k)) <= 0, f"Constraint1_{j}"
        prob += pulp.lpSum(-Psi[idx+1] * G[i,j] * U[i] for i in range(k)) <= -1, f"Constraint2_{j}"
    prob += pulp.lpSum(G[i,b] * U[i] for i in range(k)) == 1, f"Constraint3"
    for j in Y:
        j = int(j)
        prob += pulp.lpSum(G[i,j] * U[i] for i in range(k)) <= 1, f"Constraint4_{j}"
        prob += pulp.lpSum(-G[i,j] * U[i] for i in range(k)) <= 1, f"Constraint5_{j}"

    # Solve the LP
    result_status = prob.solve()
    if DEBUG:
        print("Status:", pulp.LpStatus[result_status])
        # print("Optimal Objective Value:", pulp.value(prob.objective))
    
    if pulp.LpStatus[result_status] == "Optimal":
    # Extract and print solution for U.
        solution_U = [pulp.value(u) for u in U]
        if DEBUG:
        # print("Solution U:", solution_U)
            print("Optimal Objective Value:", pulp.value(prob.objective))
            print('G:\n',G)
            print('Ψ',Psi)
            print('a,b',a,b)
        return pulp.value(prob.objective)
    else:
        if DEBUG:
            print("LP did not find an optimal solution.")
        return -1


# n=9;k=4
# solve(n,k)

# %%
import pandas as pd
import pickle
def ds(n,k, samples):
    df = pd.DataFrame()
    for i in range(samples):
        print(f'{i}/{samples}')
        P, results = solve(n,k)
        row_data = {f'val{i}': [results[i]] for i in range(len(results))}
        row_data['P'] = [P]
        df = pd.concat([df, pd.DataFrame(row_data)], ignore_index=True)

        with open(f'data_{n}_{k}_{samples}.pkl', 'wb') as f:
            pickle.dump(df, f)
    return df

# %%
D = ds(9,4, 100)
# Out:
# 0/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 107 bounded solutions found
# 10000 attempts reached
# 204 bounded solutions found
# G:
#  [[  1.   0.   0.   0.   7.  47. -92. -49.  56.]
#  [  0.   1.   0.   0.  25. -30.  -8. -77. -52.]
#  [  0.   0.   1.   0. -88.  25.  -7.  60.  38.]
#  [  0.   0.   0.   1. -74. -27.  47.  58.  33.]]
# Ψ [-1 -1 -1  1 -1]
# a,b 7 1
# X [4.0, 5.0, 6.0, 8.0]
# Y [0, 2, 3]
# 1/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 105 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -47.   6. -33. -85.  18.]
#  [  0.   1.   0.   0.  95.  83. -70. -70.  68.]
#  [  0.   0.   1.   0. -35.  60. -36. -95. -28.]
#  [  0.   0.   0.   1.  18. -42.  36. -13. -50.]]
# Ψ [-1 -1 -1 -1 -1]
# a,b 7 3
# X [4.0, 5.0, 6.0, 8.0]
# Y [0, 1, 2]
# 2/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 112 bounded solutions found
# 10000 attempts reached
# 205 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -82. -18. -40.  65.  94.]
#  [  0.   1.   0.   0.  68.   2.  25. -72.  30.]
#  [  0.   0.   1.   0.  38.  33.  -5.  85.  58.]
#  [  0.   0.   0.   1.  30. -72.  89.  27.  53.]]
# Ψ [ 1  1  1 -1 -1]
# a,b 8 7
# X [1.0, 4.0, 5.0, 6.0]
# Y [0, 2, 3]
# 3/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 99 bounded solutions found
# 10000 attempts reached
# 200 bounded solutions found
# 15000 attempts reached
# 312 bounded solutions found
# 20000 attempts reached
# 418 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -89.  83.  58.  63.  50.]
#  [  0.   1.   0.   0.   8. -56. -90.  83.  87.]
#  [  0.   0.   1.   0.  51.  16.  40. -27.  85.]
#  [  0.   0.   0.   1.  76.  32. -27. -68. -67.]]
# Ψ [ 1  1 -1  1  1]
# a,b 5 3
# X [4.0, 6.0, 7.0, 8.0]
# Y [0, 1, 2]
# 4/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 87 bounded solutions found
# 10000 attempts reached
# 200 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -79.  45.  29. -84. -45.]
#  [  0.   1.   0.   0. -42. -97. -68.   8.  38.]
#  [  0.   0.   1.   0. -93. -64.  43.  58.  77.]
#  [  0.   0.   0.   1.  80.  52. -16.  88. -28.]]
# Ψ [ 1  1  1  1 -1]
# a,b 7 8
# X [3.0, 4.0, 5.0, 6.0]
# Y [0, 1, 2]
# 5/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 118 bounded solutions found
# 10000 attempts reached
# 207 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  18.  82.  30.   5.   8.]
#  [  0.   1.   0.   0. -90. -34.  71. -85. -43.]
#  [  0.   0.   1.   0.  52.  14. -11.  32. -89.]
#  [  0.   0.   0.   1. -21.  62.  35.  67.  57.]]
# Ψ [1 1 1 1 1]
# a,b 5 0
# X [4.0, 6.0, 7.0, 8.0]
# Y [1, 2, 3]
# 6/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 109 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  67.  92. -63. -94.  48.]
#  [  0.   1.   0.   0.  35. -61. -57.  47. -38.]
#  [  0.   0.   1.   0. -64. -31. -70.  19.  15.]
#  [  0.   0.   0.   1.   2.  75.  83.  86. -52.]]
# Ψ [-1  1  1  1  1]
# a,b 6 5
# X [1.0, 2.0, 4.0, 7.0]
# Y [0, 3, 8]
# 7/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 103 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  79. -91.  26.  26.  -3.]
#  [  0.   1.   0.   0.  25.  -9. -40. -44.  26.]
#  [  0.   0.   1.   0. -66.  16.  33. -73. -18.]
#  [  0.   0.   0.   1.  50. -35.  28. -85. -75.]]
# Ψ [-1 -1 -1  1  1]
# a,b 7 1
# X [4.0, 5.0, 6.0, 8.0]
# Y [0, 2, 3]
# 8/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  -9.  76.  69. -27. -62.]
#  [  0.   1.   0.   0. -63.  37. -64.  76. -48.]
#  [  0.   0.   1.   0.  24.  10.  34.  -8. -27.]
#  [  0.   0.   0.   1. -15. -86. -58. -53.  16.]]
# Ψ [-1  1  1  1  1]
# a,b 8 6
# X [2.0, 4.0, 5.0, 7.0]
# Y [0, 1, 3]
# 9/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 110 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -37.  92.  24.  32.  94.]
#  [  0.   1.   0.   0.  59. -30. -19. -24. -29.]
#  [  0.   0.   1.   0. -94. -88.  79.  11. -38.]
#  [  0.   0.   0.   1.  23. -59. -54.  16.  64.]]
# Ψ [-1  1  1 -1 -1]
# a,b 5 4
# X [1.0, 3.0, 6.0, 8.0]
# Y [0, 2, 7]
# 10/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 78 bounded solutions found
# 10000 attempts reached
# 164 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -27.  84.  53.  59.   0.]
#  [  0.   1.   0.   0.  47.   6. -14.  25. -18.]
#  [  0.   0.   1.   0. -79.  71. -48.  87.  21.]
#  [  0.   0.   0.   1.  86. -97.  28. -12.  84.]]
# Ψ [1 1 1 1 1]
# a,b 7 4
# X [2.0, 3.0, 5.0, 8.0]
# Y [0, 1, 6]
# 11/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -32. -35. -90. -15. -97.]
#  [  0.   1.   0.   0.  95. -40.  -6.  71. -83.]
#  [  0.   0.   1.   0.  71. -10.  77. -13. -20.]
#  [  0.   0.   0.   1. -35.  71.  75.   8. -72.]]
# Ψ [-1 -1 -1 -1  1]
# a,b 8 0
# X [4.0, 5.0, 6.0, 7.0]
# Y [1, 2, 3]
# 12/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 102 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -27. -21.   1.  45.  68.]
#  [  0.   1.   0.   0. -53.  43.  -9. -19.  -1.]
#  [  0.   0.   1.   0. -15. -71. -69.   2.  32.]
#  [  0.   0.   0.   1.  76. -37.  97. -77.   4.]]
# Ψ [ 1 -1  1 -1  1]
# a,b 8 1
# X [4.0, 5.0, 6.0, 7.0]
# Y [0, 2, 3]
# 13/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -14. -76.  94. -99. -91.]
#  [  0.   1.   0.   0.  37.  84. -54.  16.   2.]
#  [  0.   0.   1.   0.  36.  16. -31.  33.  53.]
#  [  0.   0.   0.   1. -62. -57.  57.  81.  17.]]
# Ψ [ 1  1  1 -1 -1]
# a,b 4 6
# X [1.0, 5.0, 7.0, 8.0]
# Y [0, 2, 3]
# 14/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 101 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  85. -49.  68. -86. -60.]
#  [  0.   1.   0.   0.  -8.  35. -11. -76.  69.]
#  [  0.   0.   1.   0.  88.  64. -98. -81.  91.]
#  [  0.   0.   0.   1.  88.  80. -12.  91.  53.]]
# Ψ [1 1 1 1 1]
# a,b 4 7
# X [3.0, 5.0, 6.0, 8.0]
# Y [0, 1, 2]
# 15/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 107 bounded solutions found
# 10000 attempts reached
# 217 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -91.  25. -43.  61. -60.]
#  [  0.   1.   0.   0.  28.  30.  -5.  36.  20.]
#  [  0.   0.   1.   0. -82. -96.  26.  77. -92.]
#  [  0.   0.   0.   1. -26.  -8.  41. -27.  18.]]
# Ψ [ 1  1  1  1 -1]
# a,b 7 6
# X [1.0, 4.0, 5.0, 8.0]
# Y [0, 2, 3]
# 16/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 85 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  85. -72. -29.  10.  84.]
#  [  0.   1.   0.   0. -42.  52. -18. -54. -83.]
#  [  0.   0.   1.   0. -28. -28.  79.  50.  31.]
#  [  0.   0.   0.   1.  15.  71. -35.  25.  -2.]]
# Ψ [1 1 1 1 1]
# a,b 6 4
# X [1.0, 5.0, 7.0, 8.0]
# Y [0, 2, 3]
# 17/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 102 bounded solutions found
# 10000 attempts reached
# 195 bounded solutions found
# 15000 attempts reached
# 284 bounded solutions found
# 20000 attempts reached
# 385 bounded solutions found
# 25000 attempts reached
# 493 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  69. -98.  13.  92. -60.]
#  [  0.   1.   0.   0.  64.  14. -35. -91. -41.]
#  [  0.   0.   1.   0. -29.  19. -98.  50.  34.]
#  [  0.   0.   0.   1. -58. -28.  39.  72.  92.]]
# Ψ [-1  1  1 -1 -1]
# a,b 6 1
# X [4.0, 5.0, 7.0, 8.0]
# Y [0, 2, 3]
# 18/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  -5.  64.  64. -99.  37.]
#  [  0.   1.   0.   0.  57.  67.  34. -97.  19.]
#  [  0.   0.   1.   0. -23. -98.  75.   2. -71.]
#  [  0.   0.   0.   1. -43. -49. -30. -36.  88.]]
# Ψ [-1  1  1  1  1]
# a,b 7 5
# X [1.0, 4.0, 6.0, 8.0]
# Y [0, 2, 3]
# 19/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -31.  46. -70.  81.  26.]
#  [  0.   1.   0.   0. -83.  -5. -23. -82. -30.]
#  [  0.   0.   1.   0. -49.  69. -38.  74.  -2.]
#  [  0.   0.   0.   1.  40. -20. -71.   8.   8.]]
# Ψ [-1 -1  1 -1 -1]
# a,b 6 3
# X [4.0, 5.0, 7.0, 8.0]
# Y [0, 1, 2]
# 20/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -94. -70.  26. -23.  19.]
#  [  0.   1.   0.   0. -86.  99.   4.  35. -97.]
#  [  0.   0.   1.   0.  50. -27.  11.  79. -72.]
#  [  0.   0.   0.   1.  22.  30. -50. -78. -78.]]
# Ψ [-1 -1 -1  1 -1]
# a,b 8 0
# X [4.0, 5.0, 6.0, 7.0]
# Y [1, 2, 3]
# 21/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 95 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  56.  54.  33. -77. -12.]
#  [  0.   1.   0.   0. -61. -13.  69. -24.  16.]
#  [  0.   0.   1.   0. -57. -99. -61.  39. -35.]
#  [  0.   0.   0.   1.  -3.  58. -56. -10.  46.]]
# Ψ [-1 -1 -1  1  1]
# a,b 7 0
# X [4.0, 5.0, 6.0, 8.0]
# Y [1, 2, 3]
# 22/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 93 bounded solutions found
# 10000 attempts reached
# 182 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -50.   5.  89.   2. -58.]
#  [  0.   1.   0.   0.  -7. -68. -56. -17.   5.]
#  [  0.   0.   1.   0.  91. -89. -95.  74. -77.]
#  [  0.   0.   0.   1. -25.  13.  83. -31.  72.]]
# Ψ [-1  1  1 -1 -1]
# a,b 5 8
# X [1.0, 3.0, 6.0, 7.0]
# Y [0, 2, 4]
# 23/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 116 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  -5. -65. -25.  65.  92.]
#  [  0.   1.   0.   0.  95.  14.  41. -63. -42.]
#  [  0.   0.   1.   0.  54. -61. -31. -33. -43.]
#  [  0.   0.   0.   1. -94.  97. -56.   3.  -4.]]
# Ψ [-1  1  1  1  1]
# a,b 6 7
# X [1.0, 3.0, 5.0, 8.0]
# Y [0, 2, 4]
# 24/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[   1.    0.    0.    0.  -98. -100.   38.    1.   12.]
#  [   0.    1.    0.    0.   52.   81.   72.  -63.   20.]
#  [   0.    0.    1.    0.  -81.   21.   38.  -66.   84.]
#  [   0.    0.    0.    1.   12.   75.  -47.   69.  -56.]]
# Ψ [-1  1  1  1  1]
# a,b 4 7
# X [0.0, 2.0, 6.0, 8.0]
# Y [1, 3, 5]
# 25/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 109 bounded solutions found
# 10000 attempts reached
# 207 bounded solutions found
# 15000 attempts reached
# 320 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  39.  86. -67. -17. -96.]
#  [  0.   1.   0.   0.  97.  -6.  24. -90.  28.]
#  [  0.   0.   1.   0. -13.  11.  44. -37.  23.]
#  [  0.   0.   0.   1.  21. -95.  24. -42. -63.]]
# Ψ [-1  1  1  1  1]
# a,b 7 8
# X [1.0, 4.0, 5.0, 6.0]
# Y [0, 2, 3]
# 26/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0.   2. -40. -71. -27. -27.]
#  [  0.   1.   0.   0.  86.  33.  40.  50.  12.]
#  [  0.   0.   1.   0.  85. -59.  52. -89. -24.]
#  [  0.   0.   0.   1.  37.  81. -62.  39.  77.]]
# Ψ [ 1  1  1  1 -1]
# a,b 4 6
# X [1.0, 5.0, 7.0, 8.0]
# Y [0, 2, 3]
# 27/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 106 bounded solutions found
# 10000 attempts reached
# 217 bounded solutions found
# 15000 attempts reached
# 335 bounded solutions found
# G:
#  [[   1.    0.    0.    0.   94. -100.   80.   82.   48.]
#  [   0.    1.    0.    0.   -7.  -65.   82.  -93.   79.]
#  [   0.    0.    1.    0.  -89.   -5.   18.   67.  -75.]
#  [   0.    0.    0.    1.   26.   40.   88.  -32.  -77.]]
# Ψ [-1  1  1  1  1]
# a,b 5 8
# X [0.0, 2.0, 6.0, 7.0]
# Y [1, 3, 4]
# 28/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -16. -71.  37. -90. -18.]
#  [  0.   1.   0.   0.  19. -61.  68.   3. -27.]
#  [  0.   0.   1.   0. -16.  -2.  -1.  56.  76.]
#  [  0.   0.   0.   1. -73.  24.  40. -39. -76.]]
# Ψ [ 1 -1 -1 -1  1]
# a,b 6 1
# X [4.0, 5.0, 7.0, 8.0]
# Y [0, 2, 3]
# 29/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 114 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  72.  32. -95.  25. -52.]
#  [  0.   1.   0.   0.  -7.  41. -38.  88.  69.]
#  [  0.   0.   1.   0. -34.  -8.  75.  73.  29.]
#  [  0.   0.   0.   1. -11. -85. -46. -42.   3.]]
# Ψ [ 1  1  1 -1 -1]
# a,b 7 6
# X [2.0, 4.0, 5.0, 8.0]
# Y [0, 1, 3]
# 30/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  16.   6.  30.  20.  61.]
#  [  0.   1.   0.   0.  88.  36.   1. -60.  31.]
#  [  0.   0.   1.   0.  -7. -34. -84. -44.  59.]
#  [  0.   0.   0.   1. -86.  62.  27.  57.  53.]]
# Ψ [1 1 1 1 1]
# a,b 8 4
# X [3.0, 5.0, 6.0, 7.0]
# Y [0, 1, 2]
# 31/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -19.  47. -79. -40. -13.]
#  [  0.   1.   0.   0. -18.  68.  14.  13.  61.]
#  [  0.   0.   1.   0.  93.  39.  80.   5.  63.]
#  [  0.   0.   0.   1. -25. -77.  54.  85. -86.]]
# Ψ [ 1  1 -1 -1  1]
# a,b 5 0
# X [4.0, 6.0, 7.0, 8.0]
# Y [1, 2, 3]
# 32/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 82 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -86. -53.  16. -80.  30.]
#  [  0.   1.   0.   0.  17. -82. -69.  20. -36.]
#  [  0.   0.   1.   0.  20.  60.  54. -51.  43.]
#  [  0.   0.   0.   1. -49.  14. -29.  -4. -84.]]
# Ψ [-1  1  1 -1  1]
# a,b 7 6
# X [2.0, 4.0, 5.0, 8.0]
# Y [0, 1, 3]
# 33/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 91 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -26.  40.   1.   7. -18.]
#  [  0.   1.   0.   0.  96.  84.  -1. -65.  78.]
#  [  0.   0.   1.   0. -50. -73. -36.  39.  -3.]
#  [  0.   0.   0.   1. -40.  87.  89. -32. -67.]]
# Ψ [-1  1  1 -1 -1]
# a,b 4 7
# X [2.0, 3.0, 5.0, 8.0]
# Y [0, 1, 6]
# 34/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  83.  -1. -49.  60. -57.]
#  [  0.   1.   0.   0.  26. -59. -47. -82. -21.]
#  [  0.   0.   1.   0. -76. -18.  31.  16. -44.]
#  [  0.   0.   0.   1.   6.  44. -43.   2.  63.]]
# Ψ [-1  1 -1 -1  1]
# a,b 6 4
# X [1.0, 5.0, 7.0, 8.0]
# Y [0, 2, 3]
# 35/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 96 bounded solutions found
# 10000 attempts reached
# 191 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -69.  70. -77.   3. -36.]
#  [  0.   1.   0.   0.  12. -72.  53.  33. -93.]
#  [  0.   0.   1.   0.  -6.  53. -10. -58.  87.]
#  [  0.   0.   0.   1.  25.  47. -69. -22.  36.]]
# Ψ [-1  1  1  1  1]
# a,b 7 8
# X [1.0, 2.0, 3.0, 6.0]
# Y [0, 4, 5]
# 36/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  39.  71. -47. -75.  29.]
#  [  0.   1.   0.   0.  31.  20.  74. -20.  36.]
#  [  0.   0.   1.   0. -43. -25.  29. -11. -36.]
#  [  0.   0.   0.   1.  -9.  57.  -6.  47.  -8.]]
# Ψ [ 1  1  1 -1 -1]
# a,b 5 8
# X [0.0, 4.0, 6.0, 7.0]
# Y [1, 2, 3]
# 37/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  72.  50. -86. -63.  38.]
#  [  0.   1.   0.   0.   5. -42.  83.  73.  63.]
#  [  0.   0.   1.   0. -29.  75.  81.  -2.  16.]
#  [  0.   0.   0.   1.  -4.  23. -73.  87.   5.]]
# Ψ [1 1 1 1 1]
# a,b 8 5
# X [1.0, 4.0, 6.0, 7.0]
# Y [0, 2, 3]
# 38/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 71 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  76. -69.  18.  56. -57.]
#  [  0.   1.   0.   0.  -3.  20. -71. -25. -50.]
#  [  0.   0.   1.   0.  17. -18. -25.  55. -85.]
#  [  0.   0.   0.   1. -34.  13.  46. -15.  78.]]
# Ψ [-1  1  1  1 -1]
# a,b 5 4
# X [3.0, 6.0, 7.0, 8.0]
# Y [0, 1, 2]
# 39/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -60. -71.  34.  74. -17.]
#  [  0.   1.   0.   0.  93. -25.   5.  32. -53.]
#  [  0.   0.   1.   0.   7.  75.  31. -80. -83.]
#  [  0.   0.   0.   1. -42.  -4. -28. -80.  18.]]
# Ψ [-1  1  1 -1 -1]
# a,b 8 5
# X [3.0, 4.0, 6.0, 7.0]
# Y [0, 1, 2]
# 40/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 102 bounded solutions found
# 10000 attempts reached
# 221 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -24. -23. -43.  25. -82.]
#  [  0.   1.   0.   0.  78.  61.   3.  90.  23.]
#  [  0.   0.   1.   0.  98. -75. -58.  71.  32.]
#  [  0.   0.   0.   1.  97.  52.  97. -50.  16.]]
# Ψ [ 1  1  1 -1  1]
# a,b 4 3
# X [5.0, 6.0, 7.0, 8.0]
# Y [0, 1, 2]
# 41/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -42.  88.  49. -73. -59.]
#  [  0.   1.   0.   0.  23. -34.   9.  86.  65.]
#  [  0.   0.   1.   0. -35.  26.  70. -53. -90.]
#  [  0.   0.   0.   1.  73. -98.  99. -51.  20.]]
# Ψ [ 1  1 -1 -1  1]
# a,b 6 1
# X [4.0, 5.0, 7.0, 8.0]
# Y [0, 2, 3]
# 42/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  53.  61. -48. -73. -80.]
#  [  0.   1.   0.   0. -60. -30.  80.  63.  88.]
#  [  0.   0.   1.   0.  41. -43.  44.  60. -51.]
#  [  0.   0.   0.   1.  -8.  18. -62. -38.  84.]]
# Ψ [1 1 1 1 1]
# a,b 8 5
# X [2.0, 3.0, 4.0, 7.0]
# Y [0, 1, 6]
# 43/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  49.  22. -56.  -3. -61.]
#  [  0.   1.   0.   0. -19. -54.  39.  55.  25.]
#  [  0.   0.   1.   0. -15.  11.  63. -29.  70.]
#  [  0.   0.   0.   1.  23. -57.  67.  25. -35.]]
# Ψ [ 1  1  1 -1  1]
# a,b 4 5
# X [0.0, 6.0, 7.0, 8.0]
# Y [1, 2, 3]
# 44/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 92 bounded solutions found
# 10000 attempts reached
# 195 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -55. -32. -35.  31.   0.]
#  [  0.   1.   0.   0.  65.  16.  15.  12.   4.]
#  [  0.   0.   1.   0. -37. -21.  10. -83.  17.]
#  [  0.   0.   0.   1.  28.  61.  82.  32.   2.]]
# Ψ [1 1 1 1 1]
# a,b 6 5
# X [1.0, 4.0, 7.0, 8.0]
# Y [0, 2, 3]
# 45/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 85 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -20.  80. -83.  36. -88.]
#  [  0.   1.   0.   0. -17. -19.  46. -67.  18.]
#  [  0.   0.   1.   0.  85. -35. -77.  33. -47.]
#  [  0.   0.   0.   1.  55. -64.  43.  74.  73.]]
# Ψ [ 1 -1 -1 -1 -1]
# a,b 6 1
# X [4.0, 5.0, 7.0, 8.0]
# Y [0, 2, 3]
# 46/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 93 bounded solutions found
# 10000 attempts reached
# 193 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  -7. -10. -58. -50. -91.]
#  [  0.   1.   0.   0.  76.  35.  26.  36.  70.]
#  [  0.   0.   1.   0. -62.  72.  69.  59.  32.]
#  [  0.   0.   0.   1. -60. -92.   6.  26. -68.]]
# Ψ [-1  1  1  1  1]
# a,b 8 4
# X [0.0, 5.0, 6.0, 7.0]
# Y [1, 2, 3]
# 47/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  81.  43.  31. -17.  87.]
#  [  0.   1.   0.   0.  78.  94.  40.  15. -62.]
#  [  0.   0.   1.   0.  30. -27. -34.  47.  -9.]
#  [  0.   0.   0.   1. -84.   6.  -8. -23. -24.]]
# Ψ [1 1 1 1 1]
# a,b 5 3
# X [2.0, 4.0, 7.0, 8.0]
# Y [0, 1, 6]
# 48/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  14.  13.  52. -36. -97.]
#  [  0.   1.   0.   0.  95. -90.  17.  25. -57.]
#  [  0.   0.   1.   0. -30. -93.  62.  -7.  93.]
#  [  0.   0.   0.   1. -45.  92. -30.  94.  95.]]
# Ψ [ 1  1  1 -1  1]
# a,b 7 5
# X [1.0, 4.0, 6.0, 8.0]
# Y [0, 2, 3]
# 49/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -52.  96. -75.  38. -77.]
#  [  0.   1.   0.   0.  17. -75. -40.  40. -55.]
#  [  0.   0.   1.   0. -43.  88. -82.  32. -32.]
#  [  0.   0.   0.   1.   3. -53.  94.   8.  81.]]
# Ψ [ 1 -1  1 -1  1]
# a,b 7 3
# X [4.0, 5.0, 6.0, 8.0]
# Y [0, 1, 2]
# 50/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 95 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  31. -16. -78. -61. -81.]
#  [  0.   1.   0.   0.  58.  16.  40.  53. -78.]
#  [  0.   0.   1.   0. -98.  68.  79. -48. -73.]
#  [  0.   0.   0.   1.  16.  -2. -59.   4. -84.]]
# Ψ [-1  1  1  1 -1]
# a,b 8 6
# X [2.0, 3.0, 5.0, 7.0]
# Y [0, 1, 4]
# 51/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -36.  47.  85. -81. -58.]
#  [  0.   1.   0.   0.  35. -20.  20. -44. -10.]
#  [  0.   0.   1.   0.   9. -14. -46.  32.  -1.]
#  [  0.   0.   0.   1.  61. -32.  78.  93.  97.]]
# Ψ [-1  1  1 -1 -1]
# a,b 8 7
# X [2.0, 4.0, 5.0, 6.0]
# Y [0, 1, 3]
# 52/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  26.  43. -63. -68.  18.]
#  [  0.   1.   0.   0. -49. -83.  49.  77.  32.]
#  [  0.   0.   1.   0.  19.   4.  72.  64. -22.]
#  [  0.   0.   0.   1.  65. -32. -79.  25. -93.]]
# Ψ [ 1  1  1  1 -1]
# a,b 4 5
# X [0.0, 6.0, 7.0, 8.0]
# Y [1, 2, 3]
# 53/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  77.  54. -34. -15. -88.]
#  [  0.   1.   0.   0.  29. -69. -57.  78.  47.]
#  [  0.   0.   1.   0.  53.  21.  95.  27.  12.]
#  [  0.   0.   0.   1. -88.  97.  37.  37. -84.]]
# Ψ [ 1  1  1 -1 -1]
# a,b 7 4
# X [1.0, 5.0, 6.0, 8.0]
# Y [0, 2, 3]
# 54/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 74 bounded solutions found
# 10000 attempts reached
# 185 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  99. -35.  66.  85.  79.]
#  [  0.   1.   0.   0.  10. -60.  -4. -46. -85.]
#  [  0.   0.   1.   0. -14. -41.  60. -34.  25.]
#  [  0.   0.   0.   1.  11. -73.  49.   8.  26.]]
# Ψ [-1  1  1  1 -1]
# a,b 5 8
# X [3.0, 4.0, 6.0, 7.0]
# Y [0, 1, 2]
# 55/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -54. -79.  38. -23.  80.]
#  [  0.   1.   0.   0.  31. -98. -69. -91.   1.]
#  [  0.   0.   1.   0. -58.  26. -25.  62. -77.]
#  [  0.   0.   0.   1.   6.  87.  25. -71.  38.]]
# Ψ [-1  1  1  1  1]
# a,b 7 4
# X [3.0, 5.0, 6.0, 8.0]
# Y [0, 1, 2]
# 56/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 84 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -25. -75.  46. -85. -34.]
#  [  0.   1.   0.   0.  61. -50.  83.  99.  37.]
#  [  0.   0.   1.   0.  40.  36.  27.  -7. -79.]
#  [  0.   0.   0.   1. -37.  -2.  76.  87.  64.]]
# Ψ [1 1 1 1 1]
# a,b 6 8
# X [2.0, 3.0, 4.0, 7.0]
# Y [0, 1, 5]
# 57/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -65.  38.   1. -47.  52.]
#  [  0.   1.   0.   0.  58.  28.  -4.  33.  42.]
#  [  0.   0.   1.   0.  70. -83. -33.  -8.  37.]
#  [  0.   0.   0.   1. -26. -18.  85. -14.   2.]]
# Ψ [1 1 1 1 1]
# a,b 8 1
# X [4.0, 5.0, 6.0, 7.0]
# Y [0, 2, 3]
# 58/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 89 bounded solutions found
# 10000 attempts reached
# 187 bounded solutions found
# 15000 attempts reached
# 285 bounded solutions found
# 20000 attempts reached
# 379 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -17. -40.  20. -45.   8.]
#  [  0.   1.   0.   0.  25. -20.  51.  -9.  48.]
#  [  0.   0.   1.   0. -36.  88. -81.  26.  -3.]
#  [  0.   0.   0.   1. -14.  26. -91. -64. -72.]]
# Ψ [1 1 1 1 1]
# a,b 8 6
# X [1.0, 4.0, 5.0, 7.0]
# Y [0, 2, 3]
# 59/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -33. -99.  96.  67.  63.]
#  [  0.   1.   0.   0. -29.  72. -73. -94.  -5.]
#  [  0.   0.   1.   0.  48.  18.  75.  -7. -13.]
#  [  0.   0.   0.   1. -98. -35. -70.   1.  52.]]
# Ψ [ 1  1  1 -1  1]
# a,b 6 8
# X [2.0, 4.0, 5.0, 7.0]
# Y [0, 1, 3]
# 60/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  72.   7. -43. -96.   5.]
#  [  0.   1.   0.   0.  61. -82.  64.  50.  85.]
#  [  0.   0.   1.   0.  37.  94.  23.  44.  -7.]
#  [  0.   0.   0.   1.   3.  41. -66.  -3.  49.]]
# Ψ [1 1 1 1 1]
# a,b 4 5
# X [0.0, 1.0, 7.0, 8.0]
# Y [2, 3, 6]
# 61/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -29.  24.  14.  81. -58.]
#  [  0.   1.   0.   0.  61.  90.  17. -26.  54.]
#  [  0.   0.   1.   0.  80. -82.  90. -65.  -9.]
#  [  0.   0.   0.   1.  10. -42. -35. -16.   7.]]
# Ψ [ 1  1 -1  1 -1]
# a,b 4 6
# X [3.0, 5.0, 7.0, 8.0]
# Y [0, 1, 2]
# 62/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 96 bounded solutions found
# G:
#  [[   1.    0.    0.    0.   79. -100.  -80.   96.  -56.]
#  [   0.    1.    0.    0.  -89.  -19.  -30.  -34.  -50.]
#  [   0.    0.    1.    0.   58.   68.  -88.  -51.   61.]
#  [   0.    0.    0.    1.  -24.   90.  -64.  -31.  -80.]]
# Ψ [-1  1  1 -1  1]
# a,b 6 8
# X [2.0, 4.0, 5.0, 7.0]
# Y [0, 1, 3]
# 63/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 110 bounded solutions found
# 10000 attempts reached
# 209 bounded solutions found
# 15000 attempts reached
# 296 bounded solutions found
# 20000 attempts reached
# 398 bounded solutions found
# 25000 attempts reached
# 508 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -82.  -2.  24. -56.  84.]
#  [  0.   1.   0.   0. -47.  76. -23.  -8. -58.]
#  [  0.   0.   1.   0.  34.  25.  -9.  48.  48.]
#  [  0.   0.   0.   1.  72.  12.   2. -91. -10.]]
# Ψ [1 1 1 1 1]
# a,b 8 6
# X [2.0, 4.0, 5.0, 7.0]
# Y [0, 1, 3]
# 64/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 108 bounded solutions found
# 10000 attempts reached
# 201 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -42. -21. -33. -50. -63.]
#  [  0.   1.   0.   0.  50.  26.  11.   9.  55.]
#  [  0.   0.   1.   0.  37.  17. -33.   9. -76.]
#  [  0.   0.   0.   1. -96. -47.  93.  63.  13.]]
# Ψ [-1  1  1  1 -1]
# a,b 8 5
# X [1.0, 4.0, 6.0, 7.0]
# Y [0, 2, 3]
# 65/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -25. -72.   8.   0.  39.]
#  [  0.   1.   0.   0.  86.  24.  -9.  89.  11.]
#  [  0.   0.   1.   0. -22.  19. -49. -78. -13.]
#  [  0.   0.   0.   1. -24.  18.  48.  35. -72.]]
# Ψ [-1  1 -1 -1 -1]
# a,b 5 7
# X [2.0, 4.0, 6.0, 8.0]
# Y [0, 1, 3]
# 66/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  17. -44. -31. -74. -33.]
#  [  0.   1.   0.   0.  19.   1.  65. -81.  22.]
#  [  0.   0.   1.   0. -15.  97. -60. -55. -33.]
#  [  0.   0.   0.   1.  36. -49. -76. -31.  33.]]
# Ψ [-1  1  1 -1  1]
# a,b 7 1
# X [0.0, 4.0, 5.0, 6.0]
# Y [2, 3, 8]
# 67/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 106 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -35.   0.  73. -13.  47.]
#  [  0.   1.   0.   0.  33.  96. -34.  -4.  46.]
#  [  0.   0.   1.   0.   8.  59.  29.  55. -76.]
#  [  0.   0.   0.   1. -22.   6.  63.  53. -28.]]
# Ψ [ 1  1  1  1 -1]
# a,b 5 4
# X [2.0, 6.0, 7.0, 8.0]
# Y [0, 1, 3]
# 68/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  77.  27. -24. -98.  23.]
#  [  0.   1.   0.   0.  88. -45. -72.  44. -43.]
#  [  0.   0.   1.   0.  42.  30.  58. -67. -97.]
#  [  0.   0.   0.   1. -15.  43. -93.   6.  74.]]
# Ψ [-1  1  1  1 -1]
# a,b 6 8
# X [1.0, 3.0, 4.0, 5.0]
# Y [0, 2, 7]
# 69/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 116 bounded solutions found
# 10000 attempts reached
# 211 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  35. -18.  32.  76.  95.]
#  [  0.   1.   0.   0.  12.   3. -58. -90. -23.]
#  [  0.   0.   1.   0.  18.  83. -80.  36.  -1.]
#  [  0.   0.   0.   1.  23.   1.  92.  33.   9.]]
# Ψ [-1  1  1  1 -1]
# a,b 7 5
# X [0.0, 1.0, 4.0, 6.0]
# Y [2, 3, 8]
# 70/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  30.  89.  49.  93.  98.]
#  [  0.   1.   0.   0. -32.  49. -89. -13. -17.]
#  [  0.   0.   1.   0.  99. -82.  62. -29.   4.]
#  [  0.   0.   0.   1. -46.  27.  96.  98. -46.]]
# Ψ [1 1 1 1 1]
# a,b 4 5
# X [1.0, 2.0, 6.0, 8.0]
# Y [0, 3, 7]
# 71/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 107 bounded solutions found
# 10000 attempts reached
# 187 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  41.  74. -55. -71. -63.]
#  [  0.   1.   0.   0.  26.  89.  71. -64.  67.]
#  [  0.   0.   1.   0.  36. -73.  86.  66.   6.]
#  [  0.   0.   0.   1.  96.  56.  -2.  90.  17.]]
# Ψ [ 1  1  1  1 -1]
# a,b 5 6
# X [0.0, 3.0, 4.0, 8.0]
# Y [1, 2, 7]
# 72/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 81 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -73.   6. -49.  74. -25.]
#  [  0.   1.   0.   0.  28. -64. -38.  36. -26.]
#  [  0.   0.   1.   0.  67. -84.  37.  -3.  78.]
#  [  0.   0.   0.   1.   9.  45.  69.  24. -30.]]
# Ψ [-1  1  1  1  1]
# a,b 5 8
# X [3.0, 4.0, 6.0, 7.0]
# Y [0, 1, 2]
# 73/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 108 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -10.  66. -94. -35.  84.]
#  [  0.   1.   0.   0. -84. -33.  17. -38.  78.]
#  [  0.   0.   1.   0. -54.  72. -35. -99.  66.]
#  [  0.   0.   0.   1.  32. -16.  11.   8. -43.]]
# Ψ [-1  1 -1 -1  1]
# a,b 7 5
# X [1.0, 4.0, 6.0, 8.0]
# Y [0, 2, 3]
# 74/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -66. -25.  35.  34.  14.]
#  [  0.   1.   0.   0.   8.  81. -95.   9. -38.]
#  [  0.   0.   1.   0.  51.  45. -72.  92. -40.]
#  [  0.   0.   0.   1.  88. -13.   9. -33.  11.]]
# Ψ [ 1 -1 -1 -1  1]
# a,b 7 0
# X [4.0, 5.0, 6.0, 8.0]
# Y [1, 2, 3]
# 75/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 107 bounded solutions found
# 10000 attempts reached
# 223 bounded solutions found
# 15000 attempts reached
# 319 bounded solutions found
# 20000 attempts reached
# 428 bounded solutions found
# 25000 attempts reached
# 530 bounded solutions found
# 30000 attempts reached
# 639 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -11.  75.  76. -75.  -2.]
#  [  0.   1.   0.   0.  39. -92.   5. -89.  84.]
#  [  0.   0.   1.   0.  62. -94.  25.  87. -63.]
#  [  0.   0.   0.   1. -83.  98.  75. -15.  90.]]
# Ψ [ 1  1  1 -1 -1]
# a,b 6 2
# X [4.0, 5.0, 7.0, 8.0]
# Y [0, 1, 3]
# 76/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  66. -30.  88.  54.  38.]
#  [  0.   1.   0.   0.  12.  74. -89. -67.  73.]
#  [  0.   0.   1.   0. -44. -67. -79.  -7. -50.]
#  [  0.   0.   0.   1. -63.   2.  96.  10. -78.]]
# Ψ [1 1 1 1 1]
# a,b 6 7
# X [0.0, 4.0, 5.0, 8.0]
# Y [1, 2, 3]
# 77/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 108 bounded solutions found
# 10000 attempts reached
# 206 bounded solutions found
# 15000 attempts reached
# 312 bounded solutions found
# 20000 attempts reached
# 402 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -24. -88.  87.  18.  94.]
#  [  0.   1.   0.   0.  12.  62. -29. -31. -54.]
#  [  0.   0.   1.   0.  29. -97.  86.  40. -63.]
#  [  0.   0.   0.   1.  57.  57.  25.  48. -50.]]
# Ψ [1 1 1 1 1]
# a,b 6 5
# X [1.0, 4.0, 7.0, 8.0]
# Y [0, 2, 3]
# 78/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 103 bounded solutions found
# 10000 attempts reached
# 217 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  68. -10.  69. -78. -57.]
#  [  0.   1.   0.   0. -27.  14.  11. -77. -86.]
#  [  0.   0.   1.   0. -74. -19.  63.  75. -32.]
#  [  0.   0.   0.   1. -53.  36.  71.  71.  90.]]
# Ψ [ 1  1  1  1 -1]
# a,b 6 4
# X [0.0, 3.0, 5.0, 8.0]
# Y [1, 2, 7]
# 79/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 85 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -32. -71.  -2. -42.  68.]
#  [  0.   1.   0.   0. -22. -97.  -7.  94.  38.]
#  [  0.   0.   1.   0.  65.  80.  33. -28. -82.]
#  [  0.   0.   0.   1. -95. -25. -87. -16.  72.]]
# Ψ [-1  1  1  1 -1]
# a,b 8 5
# X [1.0, 2.0, 4.0, 6.0]
# Y [0, 3, 7]
# 80/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 102 bounded solutions found
# 10000 attempts reached
# 185 bounded solutions found
# 15000 attempts reached
# 280 bounded solutions found
# 20000 attempts reached
# 387 bounded solutions found
# G:
#  [[  1.   0.   0.   0.   2. -34.  26.  42.  19.]
#  [  0.   1.   0.   0. -68.  40.  67.  40. -12.]
#  [  0.   0.   1.   0.   6.  95.   7. -74.  21.]
#  [  0.   0.   0.   1.  -4.  23.  25.   8. -79.]]
# Ψ [1 1 1 1 1]
# a,b 6 0
# X [4.0, 5.0, 7.0, 8.0]
# Y [1, 2, 3]
# 81/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 82 bounded solutions found
# 10000 attempts reached
# 189 bounded solutions found
# 15000 attempts reached
# 280 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  41.  -8.  -1.  44.  39.]
#  [  0.   1.   0.   0. -89.   3.  -2. -80.  80.]
#  [  0.   0.   1.   0.  43.  22.   4. -89. -98.]
#  [  0.   0.   0.   1. -24. -44.  15.  -2.  81.]]
# Ψ [ 1  1  1 -1 -1]
# a,b 4 5
# X [0.0, 6.0, 7.0, 8.0]
# Y [1, 2, 3]
# 82/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 116 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -48.  50.  50.  15.  76.]
#  [  0.   1.   0.   0. -26.  56. -40.  91.  64.]
#  [  0.   0.   1.   0.  39. -33.   6. -77. -53.]
#  [  0.   0.   0.   1. -62. -31. -70. -29.  -8.]]
# Ψ [-1  1  1  1  1]
# a,b 7 5
# X [2.0, 4.0, 6.0, 8.0]
# Y [0, 1, 3]
# 83/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  72. -65.  75. -28. -94.]
#  [  0.   1.   0.   0. -66.  73.  59. -72. -42.]
#  [  0.   0.   1.   0.  37.  66. -32.  34.  62.]
#  [  0.   0.   0.   1.  72.  38. -66.  22. -29.]]
# Ψ [ 1  1  1 -1  1]
# a,b 5 2
# X [4.0, 6.0, 7.0, 8.0]
# Y [0, 1, 3]
# 84/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 85 bounded solutions found
# 10000 attempts reached
# 188 bounded solutions found
# 15000 attempts reached
# 285 bounded solutions found
# 20000 attempts reached
# 392 bounded solutions found
# 25000 attempts reached
# 518 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -72. -50. -99. -77.  74.]
#  [  0.   1.   0.   0. -63. -32.  81.  32. -71.]
#  [  0.   0.   1.   0. -59.  92.   4.  63.  56.]
#  [  0.   0.   0.   1. -30.  86.  86. -59.  14.]]
# Ψ [-1  1  1  1  1]
# a,b 4 7
# X [1.0, 5.0, 6.0, 8.0]
# Y [0, 2, 3]
# 85/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[   1.    0.    0.    0.  -39.   38. -100.    0.    8.]
#  [   0.    1.    0.    0.    0.  -41.    7.   53.  -22.]
#  [   0.    0.    1.    0.   58.   22.  -45.  -30.   24.]
#  [   0.    0.    0.    1.  -25.  -74.   80.  -52.  -87.]]
# Ψ [-1 -1 -1 -1  1]
# a,b 8 1
# X [4.0, 5.0, 6.0, 7.0]
# Y [0, 2, 3]
# 86/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 86 bounded solutions found
# 10000 attempts reached
# 180 bounded solutions found
# 15000 attempts reached
# 269 bounded solutions found
# 20000 attempts reached
# 365 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -28. -63.  -6.  52. -52.]
#  [  0.   1.   0.   0. -41.  67. -15. -21. -26.]
#  [  0.   0.   1.   0.  87.  84.  27.  -2. -63.]
#  [  0.   0.   0.   1. -76. -76. -20.  26.  91.]]
# Ψ [-1  1  1  1  1]
# a,b 8 4
# X [0.0, 2.0, 6.0, 7.0]
# Y [1, 3, 5]
# 87/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 103 bounded solutions found
# 10000 attempts reached
# 232 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  21. -26. -37.  69.   2.]
#  [  0.   1.   0.   0. -13.  73.  98. -97.  34.]
#  [  0.   0.   1.   0.  40.  90.  62.  83. -34.]
#  [  0.   0.   0.   1.  21.  86.  64. -39.   8.]]
# Ψ [1 1 1 1 1]
# a,b 5 8
# X [3.0, 4.0, 6.0, 7.0]
# Y [0, 1, 2]
# 88/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 95 bounded solutions found
# 10000 attempts reached
# 211 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -76.  -4.  71. -67. -61.]
#  [  0.   1.   0.   0.  46.  31.  76.  65.   7.]
#  [  0.   0.   1.   0.  92.  79.  30. -67.  -6.]
#  [  0.   0.   0.   1. -47. -39. -18. -78.  35.]]
# Ψ [ 1  1  1 -1 -1]
# a,b 6 4
# X [3.0, 5.0, 7.0, 8.0]
# Y [0, 1, 2]
# 89/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  32. -53.  95.  96.   9.]
#  [  0.   1.   0.   0.  88. -98. -71.  37.  38.]
#  [  0.   0.   1.   0. -33.  62. -21. -28. -98.]
#  [  0.   0.   0.   1. -57.  81. -45.  80.  89.]]
# Ψ [ 1  1 -1  1  1]
# a,b 7 8
# X [0.0, 4.0, 5.0, 6.0]
# Y [1, 2, 3]
# 90/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 89 bounded solutions found
# 10000 attempts reached
# 196 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  28.  73.  74.  72. -84.]
#  [  0.   1.   0.   0.  94. -88. -55.  53. -24.]
#  [  0.   0.   1.   0. -69. -39.  44. -83. -55.]
#  [  0.   0.   0.   1.   9. -15. -87. -77. -29.]]
# Ψ [-1  1  1  1 -1]
# a,b 8 0
# X [3.0, 4.0, 6.0, 7.0]
# Y [1, 2, 5]
# 91/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  84.   5.  93. -23. -83.]
#  [  0.   1.   0.   0.  24.  84. -20.  74. -51.]
#  [  0.   0.   1.   0.  19. -32. -96.  62.  11.]
#  [  0.   0.   0.   1. -48. -36.   1. -69. -24.]]
# Ψ [-1  1 -1 -1 -1]
# a,b 8 3
# X [4.0, 5.0, 6.0, 7.0]
# Y [0, 1, 2]
# 92/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 118 bounded solutions found
# 10000 attempts reached
# 212 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -46.   1. -13.  21. -16.]
#  [  0.   1.   0.   0.  76. -64.  21. -84.  54.]
#  [  0.   0.   1.   0.  52.  52.  24. -69.   9.]
#  [  0.   0.   0.   1. -61.  54.   3. -93. -21.]]
# Ψ [-1 -1  1  1 -1]
# a,b 7 0
# X [4.0, 5.0, 6.0, 8.0]
# Y [1, 2, 3]
# 93/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[   1.    0.    0.    0. -100.    4.  -40.    3.   54.]
#  [   0.    1.    0.    0.  -95.  -79.  -50.   65.   64.]
#  [   0.    0.    1.    0.   72.   -8.  -66.  -32.  -54.]
#  [   0.    0.    0.    1.   65.   85.   34.   48.    1.]]
# Ψ [-1  1 -1  1 -1]
# a,b 6 4
# X [2.0, 5.0, 7.0, 8.0]
# Y [0, 1, 3]
# 94/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 88 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -72.  16. -61. -68. -34.]
#  [  0.   1.   0.   0. -36. -75.   8. -88. -70.]
#  [  0.   0.   1.   0.  37.   5.  93.  42. -33.]
#  [  0.   0.   0.   1. -79.  32. -39.  74. -76.]]
# Ψ [-1 -1 -1 -1 -1]
# a,b 8 3
# X [4.0, 5.0, 6.0, 7.0]
# Y [0, 1, 2]
# 95/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -76.  96. -50.  -5. -22.]
#  [  0.   1.   0.   0.  45. -13. -35. -67. -67.]
#  [  0.   0.   1.   0. -76. -20. -14. -59. -74.]
#  [  0.   0.   0.   1.  64.  -6.  79.  34.  38.]]
# Ψ [ 1  1 -1 -1 -1]
# a,b 4 3
# X [1.0, 6.0, 7.0, 8.0]
# Y [0, 2, 5]
# 96/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 116 bounded solutions found
# 10000 attempts reached
# 226 bounded solutions found
# G:
#  [[  1.   0.   0.   0.  51. -24. -53. -82.  28.]
#  [  0.   1.   0.   0.  98.  25.  46.  93.  57.]
#  [  0.   0.   1.   0. -97.  38. -32. -39.  74.]
#  [  0.   0.   0.   1.  65.  -3.   2.  42. -42.]]
# Ψ [1 1 1 1 1]
# a,b 4 8
# X [1.0, 3.0, 5.0, 7.0]
# Y [0, 2, 6]
# 97/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -69.  79. -98.  86. -86.]
#  [  0.   1.   0.   0.   0. -33.   3.  15.  32.]
#  [  0.   0.   1.   0. -38.  65.  36. -95. -62.]
#  [  0.   0.   0.   1.  89.  93. -92. -17.  15.]]
# Ψ [-1  1  1  1  1]
# a,b 6 8
# X [1.0, 2.0, 5.0, 7.0]
# Y [0, 3, 4]
# 98/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 106 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -30.  63.  92. -46. -87.]
#  [  0.   1.   0.   0.  91. -21.  56.  83.  70.]
#  [  0.   0.   1.   0. -15.  13.  75. -36. -11.]
#  [  0.   0.   0.   1. -72. -76. -38.  97. -92.]]
# Ψ [ 1  1  1  1 -1]
# a,b 6 7
# X [2.0, 4.0, 5.0, 8.0]
# Y [0, 1, 3]
# 99/100
# solving n,k = (9, 4)
# over m = [2, 3, 4, 5]
# 0 attempts reached
# 0 bounded solutions found
# 5000 attempts reached
# 111 bounded solutions found
# 10000 attempts reached
# 192 bounded solutions found
# G:
#  [[  1.   0.   0.   0. -97.   0.  89.  14.  42.]
#  [  0.   1.   0.   0. -81.   8. -47. -16.  40.]
#  [  0.   0.   1.   0.  24. -13.  39. -47. -62.]
#  [  0.   0.   0.   1. -88.   1. -74.  88. -16.]]
# Ψ [-1  1  1  1  1]
# a,b 4 7
# X [1.0, 2.0, 6.0, 8.0]
# Y [0, 3, 5]

# %%
print(D)
# Out:
#                                                     P        val1        val2  \
# 0   [[94, -95, 96, -52, 33], [85, -18, 13, 93, -70...   54.996822   53.154904
# 1   [[-34, -30, -19, 16, 29], [70, -17, 22, 35, -4...    4.094484    4.805698
# 2   [[95, 83, 63, 56, 73], [-89, 76, -18, -8, -23]...  130.366941  129.406725
# 3   [[-9, 51, 72, 16, -18], [37, -9, -58, -12, 72]...   39.501072   39.338597
# 4   [[-28, -89, 49, -18, -99], [47, 29, 63, -15, -...   97.032309   97.478420
# ..                                                ...         ...         ...
# 95  [[10, 49, -69, -65, 35], [-92, -31, -88, -43, ...  100.225813   98.008025
# 96  [[-19, -56, 94, 85, -72], [80, 28, -30, 29, 54...   22.226162   44.262716
# 97  [[-100, 50, -74, -18, -95], [95, 63, 29, 91, 3...  115.218388  119.056212
# 98  [[2, -30, 89, 55, 37], [51, -2, 79, -50, 37], ...   19.529713   27.779706
# 99  [[-32, -62, 63, 32, 3], [95, -12, -63, 62, 95]...    4.526065  124.477338
#
#           val3        val4
# 0    63.722529  104.750000
# 1   119.525016  118.625083
# 2   169.803619  327.015545
# 3    39.320867   78.696244
# 4   117.925050  296.611389
# ..         ...         ...
# 95  112.697459  137.113636
# 96   61.624339   96.624096
# 97  125.645486  127.403306
# 98   26.531154   27.309153
# 99  345.697256  326.175689
#
# [100 rows x 5 columns]
